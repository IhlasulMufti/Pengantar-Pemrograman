# %% [markdown]
# <a href="https://colab.research.google.com/github/IhlasulMufti/Pengantar-Pemrograman/blob/main/Python/2022/Pertemuan_2_Conditional_Statement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Cara Penggunaan Google Colab !!**
#
# **klik tanda 🔽 untuk expand program**
# > contoh: 🔽 A. Identifier
#
# **cara menjalankan program:**
# * klik  icon ▶️ di bagian sudut kiri atas
# * Ketik Cmd/Ctrl+Enter untuk menjalankan sel di tempatnya;
# * Ketik Shift+Enter untuk menjalankan sel dan memindahkan fokus ke sel berikutnya (menambahkan satu jika tidak ada);
# * Ketik Alt+Enter untuk menjalankan sel dan menyisipkan sel kode baru tepat di bawahnya.
# * note : biasanya running pertama kali agak lama
#
#
#
# <font color="red" size=4>
# Silahkan pelajari programnya, BOLEH diubah-ubah isinya. Tidak akan berpengaruh ke file asli, reload page untuk mengembalikan file asli

# %% [markdown]
# # **A. Conditional Statement**
# Conditional statement (yang dalam bahasa indonesia disebut pernyataan bersyarat atau pengkondisian) adalah fitur dari bahasa pemrograman yang melakukan perhitungan atau tindakan yang berbeda tergantung pada kondisi yang ditentukan programmer. Pengkondisian membuat program memiliki cabang yang masing-masing akan tereksekusi jika persyaratannya terpenuhi.
#
# bahasa pemrograman seperti C, C++, dan Java setidaknya memiliki fitur conditional statement seperti if statement dan switch case, namun dalam bahasa python switch case baru di adaptasi pada versi 3.10 keatas yang dikenal sebagai “structural pattern matching” atau “match case”. Artinya, pada versi sebelumnya pengkondisian hanya dapat dilakukan menggunakan if statement. Ekspresi terdiri dari satu atau beberapa operator perbandingan dan operator logika yang akan menghasilkan nilai True (benar) atau False (salah).

# %% [markdown]
# # **B. Operator Kondisi**
#  Ekspresi terdiri dari satu atau beberapa operator perbandingan dan operator logika yang akan menghasilkan nilai True (benar) atau False (salah).
#
# **Operator Perbandingan**
#
# ![Screenshot 2022-09-19 210753.png](data:image/png;base64,...)
#
# **Operator Logika**
#
# ![Screenshot 2022-09-19 210916.png](data:image/png;base64,...)
#
# **Tambahan : keyword 'is' True jika kedua nilai yang dibandingkan bernilai sama;**
#
# **contoh : 3 is 3 (True)**

# %% [markdown]
# **Operator perbandingan**

# %%
kondisi = 1 > 2
print(kondisi)
# Out:
# False

# %%
kondisi = 1 != 2 
print(kondisi)
# Out:
# True

# %%
kondisi = 1 <= 2 
print(kondisi)
# Out:
# True

# %% [markdown]
# **Operator Logika**

# %%
kondisi = True and False
print(kondisi)
# Out:
# False

# %%
kondisi = True or False
print(kondisi)
# Out:
# True

# %%
kondisi = not True # mebalikkan nilai true ke false atau sebaliknya
print(kondisi)
# Out:
# False

# %% [markdown]
# **Operator Perbandingan dan Logika**

# %%
kondisi = (1 < 2) and ("hello!" is "hello!")
print(kondisi)
# Out:
# True

# %%
# penggunaan operator logika lebih dari 1, gunakan tanda kurung agar mudah dipahami 
kondisi = ((1 > 2) or ("hello!" is "hello!")) and 3 != 4 
print(kondisi)
# Out:
# True

# %% [markdown]
# # **C. 'if' Statement**
# If statement adalah jenis pengkondisian yang paling mendasar, di mana kode dieksekusi apabila ekspresi terpenuhi atau bernilai True (benar). Pernyataan dari if statement harus memiliki indent minimal sepanjang satu spasi di awal tiap baris kode.Suatu pernyataan dapat berupa satu baris atau satu blok kode.
#
# >![Modul PP.drawio.png](data:image/png;base64,...)

# %%
kondisi = True

if (kondisi): # 'if' merupakan keyword untuk membuat conditional statement. setelah if merupakan boolean 
              #      dapat berupa operator (perbandingan/logika), variabel, langsung dengan nilai 'True' atau 'False'
  print("blok if ter-eksekusi") # blok ini di eksekusi
# 👆 bagian awal baris agak maju (memiliki indent/spasi)
print("blok utama ter-eksekusi")
# Out:
# blok if ter-eksekusi
# blok utama ter-eksekusi

# %%
kondisi = False

if (kondisi):
  print("blok if ter-eksekusi") # blok blok ini tidak dieksekusi
# 👆 bagian awal baris agak maju (memiliki indent/spasi)
print("blok utama ter-eksekusi")
# Out:
# blok utama ter-eksekusi

# %% [markdown]
# **Menggunakan Beberapa 'if' Statement**

# %%
angka = 1000

if angka < 10:
  print(angka, "adalah satuan")

if angka < 100:
  print(angka, "adalah puluhan")

if angka < 1000:
  print(angka, "adalah ratusan")

if angka < 10_000:
  print(angka, "adalah ribuan")
# Out:
# 1000 adalah ribuan

# %% [markdown]
# # **D. 'if-else' Statement**
# Conditional “if-else” digunakan ketika bagian benar dan salah dari kondisi tertentu ditentukan untuk dieksekusi. Ketika kondisinya benar, pernyataan di dalam blok 'if' dieksekusi; jika kondisinya salah, program pada blok 'else' akan dieksekusi.
#
# > ![Modul PP.drawio (6).png](data:image/png;base64,...)

# %%
kondisi = False

if (kondisi):
  print("blok if ter-eksekusi")
  
else : 
  print("blok else ter-eksekusi")

print("blok utama ter-eksekusi")
# Out:
# blok else ter-eksekusi
# blok utama ter-eksekusi

# %%
# Contoh 1
angka = 5

if angka >= 0:
    print("bilangan positif atau nol")

else:
     print(angka, "adalah bilangan negatif")
# Out:
# bilangan positif atau nol

# %%
# Contoh 2
x = 5
y = 20

if x == y:
    print("x dan y bernilai sama")

else:
     print("x tidak sama dengan y")
# Out:
# x tidak sama dengan y

# %% [markdown]
# # **E. 'if-elif-else' statement**
# Pernyataan elif memungkinkan Anda untuk memeriksa beberapa ekspresi dan mengeksekusi blok kode segera setelah salah satu kondisi mengevaluasi ke True. Dalam hal ini, kondisi if dievaluasi terlebih dahulu. Jika salah, pernyataan elif akan dieksekusi, jika itu juga salah, pernyataan else akan dieksekusi.
#
# > ![Modul PP.drawio (7).png](data:image/png;base64,...)

# %%
kondisi_if = False
kondisi_elif = True

if (kondisi_if):
  print("blok if ter-eksekusi")

elif (kondisi_elif):
  print("blok elif ter-eksekusi")
  
else : 
  print("blok else ter-eksekusi")

print("blok utama ter-eksekusi")
# Out:
# blok elif ter-eksekusi
# blok utama ter-eksekusi

# %%
# Contoh 1
angka = 0

if angka > 0:
    print(angka, "adalah bilangan positif")
    
elif angka == 0:
    print(angka, "adalah bilangan nol")

else:
     print(angka, "adalah bilangan negatif")
# Out:
# 0 adalah bilangan nol

# %% [markdown]
# # **F. Nested IF Statement**
# Pernyataan 'if' bersarang adalah pernyataan dimana terdapat pernyataan 'if' di dalam pernyataan 'if' lainnya. Ini digunakan ketika variabel harus diproses lebih dari sekali. Pernyataan 'if', 'if-else', dan 'if…elif…else' dapat digunakan dalam blok 'if', 'elif', 'else' untuk membuat kondisi bersarang tanpa batas jumlah tumpukan.
#
# >![Modul PP.drawio (8).png](data:image/png;base64,...)

# %%
kondisi_luar = True
kondisi_dalam = True

if (kondisi_luar):
  print("blok if 'luar' ter-eksekusi")
  
  if (kondisi_dalam):
    print("blok if 'dalam' ter-eksekusi")

else : 
  print("blok else ter-eksekusi")

print("blok utama ter-eksekusi")
# Out:
# blok if 'luar' ter-eksekusi
# blok if 'dalam' ter-eksekusi
# blok utama ter-eksekusi

# %%
# Contoh 1
angka = 0

if angka >= 0:
    print(angka, "adalah bilangan positif")
    if angka == 0:
        print(angka, "adalah bilangan nol")
else:
     print(angka, "adalah bilangan negatif")
# Out:
# 0 adalah bilangan positif
# 0 adalah bilangan nol

# %%
# Contoh 2
angka = 4

if angka >= 0:
    print(angka, "adalah bilangan positif")

    if (angka % 2) == 0:
        print(angka, "adalah bilangan genap positif")
else:
     print(angka, "adalah bilangan negatif")
# Out:
# 4 adalah bilangan positif
# 4 adalah bilangan genap positif

# %% [markdown]
# # **G. Shorthand 'if' statement**
# Shorthand if statement digunakan ketika hanya satu statement yang perlu dieksekusi di dalam blok if. Pernyataan ini dapat disertakan di baris yang sama dengan pernyataan If. Pernyataan

# %%
kondisi = True
if kondisi: print("blok if ter-eksekusi")
# Out:
# blok if ter-eksekusi

# %%
a = 123
if a > 100: print(a, "lebih besar dari seratus")
# Out:
# 123 lebih besar dari seratus

# %% [markdown]
# # **H. Shorthand 'if-else'**
# Shorthand if-else digunakan untuk menyebutkan pernyataan If-else dalam satu baris di mana hanya ada satu pernyataan untuk dieksekusi di blok if dan else.

# %%
kondisi = False
print("blok if ter-eksekusi") if kondisi else print("blok else ter-eksekusi")
# Out:
# blok else ter-eksekusi

# %%
a = 123
print(a, " besar seratus")if a > 100 else print(a, " kecil seratus")
# Out:
# 123  besar seratus

# %% [markdown]
# # **I. Match Case**
# Pernyataan switch mengevaluasi ekspresi, mencocokkan nilai ekspresi terhadap serangkaian klausa kasus, dan mengeksekusi pernyataan setelah klausa kasus pertama dengan nilai yang cocok, hingga pernyataan break ditemukan. Klausa default dari pernyataan switch akan dilompati jika tidak ada kasus yang cocok dengan nilai ekspresi.
#
# > ![Modul PP.drawio (9).png](data:image/png;base64,...)

# %% [markdown]
# <font color="red" size=4>
# note: Google colab menggunakan Python v3.7 sehingga tidak mendukung match case. gunakan Python v3.10 agar dapat menggunakan match case
#
# download Python 3.10 disini: https://www.python.org/downloads/

# %%
# variabel = 3

# match variabel:
#     case 1:
#          print("case 1 terpenuhi")
#     case 2:
#          print("case 2 terpenuhi")
#     case 3:
#          print("case 3 terpenuhi")
#     case 4:
#          print("case 4 terpenuhi")
#     case _:
#          print("tidak ada case yang terpenuhi, menjalankan kondisi default")

# %%
# !python --version
# Out:
# Python 3.7.14

# %% [markdown]
# # **Contoh Kasus**
#
# Buatlah program yang dapat menecek kelulusan siswa berdasarkan aturan berikut:
# * Mengerjakan tugas Mid dan Kehadiran >= 80% dari 16 pertemuan dan nilai rata" > 70
# * Mengerjakan tugas Mid Kehadiran >= 60% dari 16 pertemuan dan nilai rata" > 85
# * Tidak Mengerjakan tugas Mid dan Kehadiran >= 60% dan mengikuti lomba dan nilai rata" > 60
#
# >Format input. terdapat empat inputan yaitu:
# * nama : string
# * tugas_mid : string ("ya"/"tidak")
# * kehadiran : int (antara 0 - 16)
# * nilai_avg : float (antara 0 - 100)
# * lomba : string ("ya" / "tidak")
#
# >Format output :
#
# >jika input valid : cetak "[nama siswa] dinyatakan [lulus/tidak]"
#
# >jika input tidak valid : cetak pemberitahuan input yang salah cth: "kehadiran harus dalam rentang 0 - 16"

# %%
# membuat variable untuk menampung nilai input
nama = input("Nama siswa : ")
tugas_mid = input("Tugas mid (ya/tidak) : ")
kehadiran = int(input("Kehadiran (0 - 16) : "))
nilai_avg = float(input("Nilai rata-rata (0 - 100) : ")) 
lomba = input("Mengikuti lomba (ya/tidak) : ")

print("-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-")

# konversi nilai kehadiran kedalam persentase
prst_kehadiran = kehadiran/16 * 100

# validasi inputan
tugas_mid_valid = (tugas_mid == "ya" or tugas_mid == "tidak")
kehadiran_valid = (kehadiran >= 0 and kehadiran <= 16)
nilai_avg_valid = (nilai_avg >= 0 and nilai_avg <= 100)
lomba_valid = (lomba == "ya" or lomba == "tidak")

input_valid = tugas_mid_valid and kehadiran_valid and nilai_avg_valid and lomba_valid

if input_valid:

  if (tugas_mid == "ya") and (prst_kehadiran >= 80) and (nilai_avg > 70): # cek kondisi lulus ke-1
    print("\n", nama, "dinyatakan lulus!")

  elif (tugas_mid == "ya") and (prst_kehadiran >= 60) and (nilai_avg > 85): # cek kondisi lulus ke-2
    print("\n", nama, "dinyatakan lulus!")

  elif (prst_kehadiran >= 60) and (nilai_avg > 65) and (lomba == "ya"): # cek kondisi lulus ke-3
    print("\n", nama, "dinyatakan lulus!")

  else:
    print("\n", nama, "dinyatakan tidak lulus!")

else :
  print("\nError: Input tidak valid")

  if not tugas_mid_valid:
    print("Tugas mid harus antara 'ya' dan 'tidak'" )
  
  if not kehadiran_valid:
    print("Kehadiran harus dalam rentang 0 - 16")
  
  if not nilai_avg_valid:
    print("Nilai avg harus dalam rentang 0 - 100")

  if not lomba_valid:
    print("Lomba harus antara 'ya' dan 'tidak'")
# Out:
# Nama siswa : Mufti Faqih
# Tugas mid (ya/tidak) : ya
# Kehadiran (0 - 16) : 14
# Nilai rata-rata (0 - 100) : 74
# Mengikuti lomba (ya/tidak) : tidak
# -#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-
#
#  Mufti Faqih dinyatakan lulus!

# %% [markdown]
# # **Referensi Belajar Python:**
#
# YOUTUBE :
# * IDN https://www.youtube.com/playlist?list=PLZS-MHyEIRo59lUBwU-XHH7Ymmb04ffOY
# * IDN https://www.youtube.com/playlist?list=PL-CtdCApEFH_HY6bL3JER8WJOxz1nb3_H
# * ENG https://www.youtube.com/watch?v=_uQrJ0TkZlc&t=1028s
# * ENG https://www.youtube.com/watch?v=rfscVS0vtbw&t=938s
#
# WEBSITE :
# * IDN https://www.petanikode.com/tutorial/python/
# * ENG https://www.w3schools.com/python/
# * ENG https://www.programiz.com/python-programming

# %% [markdown]
# <font color='cyan' size=18 align="center">
# TERIMA KASIH
